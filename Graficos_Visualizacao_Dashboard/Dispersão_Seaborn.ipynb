# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as srn

# %%
base = pd.read_csv('co2.csv')
display(base)
# Out:
#    Plant         Type   Treatment  conc  uptake
# 0    Qn1       Quebec  nonchilled    95    16.0
# 1    Qn1       Quebec  nonchilled   175    30.4
# 2    Qn1       Quebec  nonchilled   250    34.8
# 3    Qn1       Quebec  nonchilled   350    37.2
# 4    Qn1       Quebec  nonchilled   500    35.3
# ..   ...          ...         ...   ...     ...
# 79   Mc3  Mississippi     chilled   250    17.9
# 80   Mc3  Mississippi     chilled   350    17.9
# 81   Mc3  Mississippi     chilled   500    17.9
# 82   Mc3  Mississippi     chilled   675    18.9
# 83   Mc3  Mississippi     chilled  1000    19.9
#
# [84 rows x 5 columns]

# %%
srn.scatterplot(x = base.conc , y = base.uptake, hue = base.Type)
#hue atribui cores diferentes para 'Type'
# Out:
# <Axes: xlabel='conc', ylabel='uptake'>

# %%
m = base.loc[base['Type'] == 'Mississippi']
q = base.loc[base['Type'] == 'Quebec']

# %%
fig, axes = plt.subplots(1,2)

srn.scatterplot(x = q.conc, y = q.uptake, ax=axes[0]).set(title="Quebec")
srn.scatterplot(x = m.conc, y = m.uptake, ax=axes[1]).set(title="Mississippi")

plt.tight_layout()

# %%
ch = base.loc[base['Treatment'] == 'chilled']
nc = base.loc[base['Treatment'] == 'nonchilled']

fig, axes = plt.subplots(1,2 )
                        
srn.scatterplot(x = ch.conc,y=  ch.uptake, ax = axes[0])
srn.scatterplot(x = nc.conc,y= nc.uptake, ax = axes[1])

plt.tight_layout()

# %%
base2 = pd.read_csv('esoph.csv')
base2
# Out:
#     agegp      alcgp     tobgp  ncases  ncontrols
# 0   25-34  0-39g/day  0-9g/day       0         40
# 1   25-34  0-39g/day     10-19       0         10
# 2   25-34  0-39g/day     20-29       0          6
# 3   25-34  0-39g/day       30+       0          5
# 4   25-34      40-79  0-9g/day       0         27
# ..    ...        ...       ...     ...        ...
# 83    75+      40-79       30+       1          1
# 84    75+     80-119  0-9g/day       1          1
# 85    75+     80-119     10-19       1          1
# 86    75+       120+  0-9g/day       2          2
# 87    75+       120+     10-19       1          1
#
# [88 rows x 5 columns]

# %%
srn.catplot(data = base2, x = 'alcgp', y = 'ncontrols', jitter = True)
# JITTER para os pontos no gráfico se espallharem

# %%
srn.catplot(data = base2, x = 'alcgp', y = 'ncontrols', col = 'tobgp')
# col divide os graficos emcolunas com base no paramentro que foi passado

# %%
srn.catplot(data = base2, x = 'alcgp', y = 'ncontrols',kind= 'point')
# KIND -> bar, violin, point, swarm, box, strip
