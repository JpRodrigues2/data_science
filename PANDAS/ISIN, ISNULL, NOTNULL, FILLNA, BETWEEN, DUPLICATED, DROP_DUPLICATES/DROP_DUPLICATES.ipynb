# %%
import pandas as pd
import numpy as np

df = pd.read_csv('bank.csv', sep =';',encoding = 'UTF-8'  )

# %%
df = df.sort_values('age')

# %%
df.head(10)
# Out:
#       age      job marital  education default  balance housing loan  \
# 503    19  student  single    primary      no      103      no   no
# 1900   19  student  single    unknown      no        0      no   no
# 2780   19  student  single  secondary      no      302      no   no
# 3233   19  student  single    unknown      no     1169      no   no
# 999    20  student  single  secondary      no      291      no   no
# 1725   20  student  single  secondary      no     1191      no   no
# 13     20  student  single  secondary      no      502      no   no
# 3362   21  student  single  secondary      no        6      no   no
# 2289   21  student  single  secondary      no      681      no   no
# 110    21  student  single  secondary      no     2488      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 503    cellular   10   jul       104         2     -1         0  unknown  yes
# ...

# %%
df.drop_duplicates(subset = ['age'], keep = 'first').head()


#SUBSET --> colunas a serem consideradas, por padrão, pandas verifica todas as colunas do dataframe
# Out:
#       age           job marital  education default  balance housing loan  \
# 503    19       student  single    primary      no      103      no   no
# 999    20       student  single  secondary      no      291      no   no
# 3362   21       student  single  secondary      no        6      no   no
# 2953   22       student  single   tertiary      no      691      no   no
# 2195   23  entrepreneur  single    primary      no        4     yes   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome    y
# 503    cellular   10   jul       104         2     -1         0  unknown  yes
# 999   telephone   11   may       172         5    371         5  failure   no
# 3362    unknown    9   may       622         1     -1         0  unknown   no
# 2953   cellular   19   aug       338         1     -1         0  unknown  yes
# 2195    unknown   13   may       395         2     -1         0  unknown  yes

# %%
df
